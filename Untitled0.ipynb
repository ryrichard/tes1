# %% [markdown]
# <a href="https://colab.research.google.com/github/ryrichard/tes1/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Summer Data Analysis
# 1. Plot and Visualization
# 2. Github

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Data Sets
# ##1. Tips
# ##2. Covid-19 (Real-World Dataset)

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %% [markdown]
# count plot of day

# %%
sns.countplot(tips.day)
plt.show()

# %%
sns.countplot(tips.day, palette = 'cubehelix')
#https://seaborn.pydata.org/tutorial/color_palettes.html
plt.show()

# %%
sns.countplot(tips.day, palette = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"])
plt.show()

# %%
sns.countplot(tips.day, palette = ["b", "red", "sandybrown", "skyblue"])
#https://python-graph-gallery.com/100-calling-a-color-with-seaborn/
plt.show()

# %%
sns.countplot(tips.sex)
plt.show()

# %%
#how we can check how many smokers in this dataset

sns.countplot(x='smoker',data=tips)
#or sns.countplot(tips.smoker)
plt.show()

# %% [markdown]
# Barplot with tip by day

# %%
sns.barplot(x='day', y='tip', data=tips)
plt.show()

# %%
sns.barplot(x='day', y='tip', ci=None, data=tips)
plt.show()

# %%
sns.set(rc={'figure.figsize' : (12,8)}) #Change figure size
sns.barplot(x='day', y='tip', ci=None, data=tips)
plt.show( )

# %%
sns.reset_orig()

sns.barplot(x='day', y='tip', ci=None, data=tips)
plt.show( )

# %%
plt.figure(figsize=(15,8))

sns.barplot(x='day', y='tip', ci=None, data=tips)
plt.show( )

# %%
sns.barplot(x='day', y='tip', ci=None, data=tips)
plt.show( )

# %%
sns.set_style('darkgrid')
sns.set_palette('RdBu')
sns.set_context("poster") #talk, paper, notebook

sns.barplot(x='day', y='tip', ci=None, data=tips)
plt.show( )

# %%
sns.reset_orig()
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', hue='smoker', data=tips)
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', hue='smoker', hue_order=['Yes', 'No'],data=tips)
plt.show()

# %%
#I want to change figure size
plt.figure(figsize=(20,10))

sns.scatterplot(x='total_bill', y='tip', hue='smoker', hue_order=['Yes', 'No'],data=tips)
plt.show()

# %%
plt.figure(figsize=(20,10))

sns.scatterplot(x='total_bill', y='tip', hue='smoker', hue_order=['Yes', 'No'], size='day', style='sex', data=tips)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, kind='scatter', col='smoker')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=tips, 
            kind='scatter', col='smoker', row='time')
plt.show()

# %%
path = 'https://raw.githubusercontent.com/RamiKrispin/coronavirus/master/csv/coronavirus.csv'

df = pd.read_csv(path)
df.head()
# Out:
#          date province      country   lat  long       type  cases
# 0  2020-01-22      NaN  Afghanistan  33.0  65.0  confirmed      0
# 1  2020-01-23      NaN  Afghanistan  33.0  65.0  confirmed      0
# 2  2020-01-24      NaN  Afghanistan  33.0  65.0  confirmed      0
# 3  2020-01-25      NaN  Afghanistan  33.0  65.0  confirmed      0
# 4  2020-01-26      NaN  Afghanistan  33.0  65.0  confirmed      0

# %%
df.shape
# Out:
# (112255, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112255 entries, 0 to 112254
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      112255 non-null  object
#  1   province  32747 non-null   object
#  2   country   112255 non-null  object
#  3   lat       112255 non-null  float64
#  4   long      112255 non-null  float64
#  5   type      112255 non-null  object
#  6   cases     112255 non-null  int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
sns.countplot(x=df.type)
plt.show()

# %%
sns.barplot(x='country', y='cases', data=df)
plt.show()

# %%
sns.set(rc={'figure.figsize': (40,20)})

sns.barplot(x='country', y='cases',ci=None, data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.set(rc={'figure.figsize': (40,20)})

sns.barplot(x='date', y='cases',ci=None, data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df1 = df[(df['country'] == 'US') | (df['country'] == 'Russia') | (df['country'] == 'Brazil' )]
df1.shape
# Out:
# (1287, 7)

# %%
df1.head()
# Out:
#             date province country     lat     long       type  cases
# 3146  2020-01-22      NaN  Brazil -14.235 -51.9253  confirmed      0
# 3147  2020-01-23      NaN  Brazil -14.235 -51.9253  confirmed      0
# 3148  2020-01-24      NaN  Brazil -14.235 -51.9253  confirmed      0
# 3149  2020-01-25      NaN  Brazil -14.235 -51.9253  confirmed      0
# 3150  2020-01-26      NaN  Brazil -14.235 -51.9253  confirmed      0

# %%
sns.lineplot(x='date', y='cases', hue='country', ci=None, data=df1 )
plt.xticks(rotation=90)
plt.show()

# %%
sns.reset_orig()
sns.barplot(x='country',y='cases',hue='type',ci=None,data=df1)
plt.show()

# %%
sns.relplot(x='date', y='cases', row='country', ci=None, 
            height=5,
            aspect=5,
            kind='line', data=df1)
plt.xticks(rotation=90)
plt.show()
